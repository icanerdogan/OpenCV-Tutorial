# %%
pip install pyzbar

# %% [markdown]
# ### Barcode Scanner

# %%
from pyzbar import pyzbar
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('images/qr.png')

barcodes = pyzbar.decode(image)

for barcode in barcodes:
    
    # Rectangle
    (x, y, w, h) = barcode.rect
    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

    # Read to Data
    barcodeData = barcode.data.decode('utf-8')
    barcodeType = barcode.type
    
    #Write to Data
    text = "{} ( {} )".format(barcodeData, barcodeType)
    cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 1)

    print("Information : \n Found Type : {} Barcode : {}".format(barcodeType, barcodeData))

        
plt.imshow(image)   
cv2.imshow("QR Code Image", image)


cv2.waitKey(0)
# Out:
# Information :
#  Found Type : QRCODE Barcode : github.com/icanerdogan
# -1
